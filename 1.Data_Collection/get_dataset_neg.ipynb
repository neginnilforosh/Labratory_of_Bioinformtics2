# %%
import requests
from requests.adapters import HTTPAdapter, Retry
import json
import re

# %% [markdown]
# ### 1. Configure retry strategy to handle temporary errors

# %%
retries = Retry(total=5, backoff_factor=0.25, status_forcelist=[500, 502, 503, 504])
session = requests.Session()
session.mount("https://", HTTPAdapter(max_retries=retries))

# %% [markdown]
# ### 2. Definition of batch size and the url from which recover the information

# %%
def get_next_link(headers):

    ''' function to get the link for the next batch of entries, the function terminates when the link is not found'''

    if "Link" in headers:
        # The regular expression is used to extract the next link for pagination
        re_next_link = re.compile(r'<(.+)>; rel="next"')
        match = re_next_link.match(headers["Link"])
        if match:
            return match.group(1)

def get_batch(batch_url):

    '''generator function that yields each batch generated with the current API call link '''

    while batch_url:
        # Run the API call
        response = session.get(batch_url)
        # Will raise an error if an error status code is obtained
        response.raise_for_status()
        # Get the total number of entries in the search
        total = response.headers["x-total-results"]
        # Yield the response and the total number of entries
        yield response, total
        # Get the link to the API call for the next data batch
        batch_url = get_next_link(response.headers)

batch_size = 500
url_neg = "https://rest.uniprot.org/uniprotkb/search?format=json&query=%28%28fragment%3Afalse%29+AND+%28length%3A%5B40+TO+*%5D%29+AND+%28taxonomy_id%3A2759%29+NOT+%28ft_signal%3A*%29+AND+%28%28cc_scl_term_exp%3ASL-0091%29+OR+%28cc_scl_term_exp%3ASL-0191%29+OR+%28cc_scl_term_exp%3ASL-0173%29+OR+%28cc_scl_term_exp%3ASL-0209%29+OR+%28cc_scl_term_exp%3ASL-0204%29+OR+%28cc_scl_term_exp%3ASL-0039%29%29+AND+%28reviewed%3Atrue%29+AND+%28existence%3A1%29%29&size=500"
output_file = "negative_dataset.tsv"
output_fasta_file="negative_dataset.fasta"

# %% [markdown]
# ### 3. Extracting data of interest from each entry. No filtering is needed

# %%
organisms=["Metazoa","Fungi","Viridiplantae"]
def extract_fields(entry):

    '''function to extract the fields of interest from the JSON of each entry '''

    pa = entry["primaryAccession"]
    name = entry["organism"]["scientificName"]
    lin = entry["organism"]["lineage"][1]
    lenn = entry["sequence"]["length"]
    hel = "False"
    for feature in entry["features"]:
        if feature["type"] == "Transmembrane":
            if feature['description'] == "Helical":
                if feature["location"]["start"]["value"] <= 90:
                    hel = "True"
                    break
    if lin in organisms:
      return (pa , name , lin , lenn , hel)
    else:
      return (pa , name , "Other" , lenn , hel)

# %% [markdown]
# ## 4. Define dataset creation: apply filters, extract fields, and save results in a TSV file and FASTA file respectively

# %%
def get_dataset(search_url, extract_function, output_file_name,output_fasta_file_name):
    '''function to get the entire dataset. It uses all the previous functions '''
    dataset_json = []
    n_total = 0
    intestation=("EntryID","OrganismName","Kingdom","SequenceLength","HelixDomain")
    with open(output_fasta_file_name,"w") as ofs_fasta:
      for batch, total in get_batch(search_url):
          batch_json = json.loads(batch.text)
          print("Status code:", batch.status_code)
          print("Content-Type:", batch.headers.get("Content-Type"))
          print("Text preview:", batch.text[:200])
          for entry in batch_json["results"]:
                n_total += 1
                dataset_json.append(extract_function(entry))
                print(">"+entry["primaryAccession"],file=ofs_fasta)
                print(entry["sequence"]["value"],file=ofs_fasta)
    ofs_fasta.close
    print(n_total)
    with open(output_file_name, "w") as ofs:
        print(*intestation, sep="\t", file=ofs)
        for entry in dataset_json:
            print(*entry, sep="\t", file=ofs)
        ofs.close

# %%
#Execute the get dataset function with desired parameters to get results
if __name__ == "__main__":
    get_dataset(url_neg, extract_fields, output_file,output_fasta_file)
# Out:
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q6YN16","secondaryAccessions":["A8K1L4","A8K8X1","A8MSV3","Q658M8","Q9BT58"],"uniProtkbId":"HSDL2_HUMAN","entryAudit":{"f
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q9P0J1","secondaryAccessions":["B3KX71","J3KPU0","Q5U5K1"],"uniProtkbId":"PDP1_HUMAN","entryAudit":{"firstPublicDate":"20
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q8WV93","secondaryAccessions":["Q8N6A3"],"uniProtkbId":"AFG1L_HUMAN","entryAudit":{"firstPublicDate":"2007-03-06","lastAn
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"O75478","secondaryAccessions":["A8MVD0","B3KMU9","Q9BVJ0","Q9UCW2","Q9UP49"],"uniProtkbId":"TAD2A_HUMAN","entryAudit":{"f
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"P20719","secondaryAccessions":["A4D179","O43367","Q96CY6"],"uniProtkbId":"HXA5_HUMAN","entryAudit":{"firstPublicDate":"19
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q7L7L0","secondaryAccessions":["B2R4S4"],"uniProtkbId":"H2A3_HUMAN","entryAudit":{"firstPublicDate":"2006-04-04","lastAnn
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q15475","secondaryAccessions":["Q53Y16","Q96H64"],"uniProtkbId":"SIX1_HUMAN","entryAudit":{"firstPublicDate":"1997-11-01"
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"P15954","secondaryAccessions":["Q6NR81"],"uniProtkbId":"COX7C_HUMAN","entryAudit":{"firstPublicDate":"1990-04-01","lastAn
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q5F1R6","secondaryAccessions":["Q3B7J9","Q6P086","Q6ZS43","Q86VC6"],"uniProtkbId":"DJC21_HUMAN","entryAudit":{"firstPubli
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q8WTV0","secondaryAccessions":["F8W8N0","Q14016","Q52LZ5","Q6KFX4"],"uniProtkbId":"SCRB1_HUMAN","entryAudit":{"firstPubli
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"O75044","secondaryAccessions":["A2RUF3"],"uniProtkbId":"SRGP2_HUMAN","entryAudit":{"firstPublicDate":"2004-06-07","lastAn
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"P50748","secondaryAccessions":["A7E2C4","B3KSG2"],"uniProtkbId":"KNTC1_HUMAN","entryAudit":{"firstPublicDate":"1996-10-01
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q9LD47","secondaryAccessions":["Q4ZJI5","Q67Y08","Q681F4","Q94A55","Q9SPD6"],"uniProtkbId":"CCS_ARATH","entryAudit":{"fir
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q8K4Z2","secondaryAccessions":["A0AA74KUW2","Q9DB97"],"uniProtkbId":"FNDC5_MOUSE","entryAudit":{"firstPublicDate":"2008-0
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"P24329","secondaryAccessions":["Q5I0D4"],"uniProtkbId":"THTR_RAT","entryAudit":{"firstPublicDate":"1992-03-01","lastAnnot
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q9LJD8","secondaryAccessions":["O81809"],"uniProtkbId":"M3KE1_ARATH","entryAudit":{"firstPublicDate":"2015-03-04","lastAn
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q9QYW0","uniProtkbId":"AATF_RAT","entryAudit":{"firstPublicDate":"2005-07-19","lastAnnotationUpdateDate":"2026-01-28","la
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"P10105","secondaryAccessions":["O97065"],"uniProtkbId":"LAB_DROME","entryAudit":{"firstPublicDate":"1989-07-01","lastAnno
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"P38111","secondaryAccessions":["D6VQD2","Q02580"],"uniProtkbId":"ATR_YEAST","entryAudit":{"firstPublicDate":"1994-10-01",
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"P53973","secondaryAccessions":["D6W1F8"],"uniProtkbId":"HDA1_YEAST","entryAudit":{"firstPublicDate":"1996-10-01","lastAnn
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"P40492","secondaryAccessions":["D6VVJ0"],"uniProtkbId":"FYV10_YEAST","entryAudit":{"firstPublicDate":"1995-02-01","lastAn
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"P10854","secondaryAccessions":["Q5T008"],"uniProtkbId":"H2B1M_MOUSE","entryAudit":{"firstPublicDate":"1989-07-01","lastAn
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q99MY0","secondaryAccessions":["Q3V487","Q80X69"],"uniProtkbId":"SPZ1_MOUSE","entryAudit":{"firstPublicDate":"2007-03-20"
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"P42580","secondaryAccessions":["A4QPC3","Q9JHF2","Q9JKW5","Q9JKW6","Q9JKW9","Q9JKX0","Q9JKX1"],"uniProtkbId":"NKX12_MOUSE
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"P46101","uniProtkbId":"DPP6_RAT","entryAudit":{"firstPublicDate":"1995-11-01","lastAnnotationUpdateDate":"2026-01-28","la
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"P35203","secondaryAccessions":["D6VZR7"],"uniProtkbId":"CBF3C_YEAST","entryAudit":{"firstPublicDate":"1994-02-01","lastAn
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"P31651","uniProtkbId":"S6A12_MOUSE","entryAudit":{"firstPublicDate":"1993-07-01","lastAnnotationUpdateDate":"2026-01-28",
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"F4IDB2","secondaryAccessions":["Q9C9D6","Q9C9D7"],"uniProtkbId":"PHL_ARATH","entryAudit":{"firstPublicDate":"2018-09-12",
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q03611","secondaryAccessions":["P90800"],"uniProtkbId":"CNG_CAEEL","entryAudit":{"firstPublicDate":"1994-02-01","lastAnno
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"P53540","secondaryAccessions":["D6W157"],"uniProtkbId":"SPC98_YEAST","entryAudit":{"firstPublicDate":"1996-10-01","lastAn
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q01956","uniProtkbId":"KCNC3_RAT","entryAudit":{"firstPublicDate":"1998-07-15","lastAnnotationUpdateDate":"2025-06-18","l
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q9UTR8","secondaryAccessions":["Q9UTX3"],"uniProtkbId":"RED1_SCHPO","entryAudit":{"firstPublicDate":"2009-02-10","lastAnn
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q5T653","secondaryAccessions":["B2RC56","Q8WUL1","Q96Q56","Q9Y311"],"uniProtkbId":"RM02_HUMAN","entryAudit":{"firstPublic
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"B9EJG8","secondaryAccessions":["B7Z4J5","B7Z4L3","B7Z692","B7Z6X6"],"uniProtkbId":"T150C_HUMAN","entryAudit":{"firstPubli
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q17784","secondaryAccessions":["A1XDB6"],"uniProtkbId":"TFP11_CAEEL","entryAudit":{"firstPublicDate":"2008-07-01","lastAn
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q9S7A9","secondaryAccessions":["Q9SMX8"],"uniProtkbId":"SPL4_ARATH","entryAudit":{"firstPublicDate":"2005-06-07","lastAnn
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q9JJI5","secondaryAccessions":["F1LQC9","Q9JIB2"],"uniProtkbId":"NMUR1_RAT","entryAudit":{"firstPublicDate":"2005-12-06",
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q9LKX9","secondaryAccessions":["O22344","Q7DLV4"],"uniProtkbId":"RBR1_MAIZE","entryAudit":{"firstPublicDate":"2008-05-20"
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"O49939","uniProtkbId":"TLP40_SPIOL","entryAudit":{"firstPublicDate":"2000-12-01","lastAnnotationUpdateDate":"2026-01-28",
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"Q9DAD6","uniProtkbId":"PROF3_MOUSE","entryAudit":{"firstPublicDate":"2004-03-29","lastAnnotationUpdateDate":"2026-01-28",
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"P83525","uniProtkbId":"FER_SCOJA","entryAudit":{"firstPublicDate":"2003-09-19","lastAnnotationUpdateDate":"2025-02-05","l
# Status code: 200
# Content-Type: application/json
# Text preview: {"results":[{"entryType":"UniProtKB reviewed (Swiss-Prot)","primaryAccession":"P00319","secondaryAccessions":["P35910"],"uniProtkbId":"APCB_GALSU","entryAudit":{"firstPublicDate":"1986-07-21","lastAnn
# 20806
